# %% [markdown]
# # Mundo 9
#
# ## Leitura e extração de dados

# %%
import pandas as pd
import os

# %%
diretorio_atual = os.getcwd()
os.chdir(diretorio_atual)

# %%
dados_bp = pd.read_csv("Csv/Mundo9dfp_cia_aberta_BPP_con_2021.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dados_bp = pd.read_csv("Csv/Mundo9dfp_cia_aberta_BPP_con_2021.csv")
#
# File c:\Users\Tiago\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\Tiago\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
# ...

# %%
dados_bp = pd.read_csv("Csv/Mundo9dfp_cia_aberta_BPP_con_2021.csv", sep = ";" , encoding="ISO-8859-1")
#Mudar a codigficação dos dados é fundamental na CVM
#Por padrão é Virgula,mas como no Brasil decimal usa ",", nos usamos ; em arquivos csv.

dados_bp
# Out:
#                   CNPJ_CIA    DT_REFER  VERSAO        DENOM_CIA  CD_CVM  \
# 0       00.000.000/0001-91  2021-12-31       2  BCO BRASIL S.A.    1023
# 1       00.000.000/0001-91  2021-12-31       2  BCO BRASIL S.A.    1023
# 2       00.000.000/0001-91  2021-12-31       2  BCO BRASIL S.A.    1023
# 3       00.000.000/0001-91  2021-12-31       2  BCO BRASIL S.A.    1023
# 4       00.000.000/0001-91  2021-12-31       2  BCO BRASIL S.A.    1023
# ...                    ...         ...     ...              ...     ...
# 101159  97.837.181/0001-47  2021-12-31       1       DEXCO S.A.   21091
# 101160  97.837.181/0001-47  2021-12-31       1       DEXCO S.A.   21091
# 101161  97.837.181/0001-47  2021-12-31       1       DEXCO S.A.   21091
# 101162  97.837.181/0001-47  2021-12-31       1       DEXCO S.A.   21091
# 101163  97.837.181/0001-47  2021-12-31       1       DEXCO S.A.   21091
#
#                                            GRUPO_DFP MOEDA ESCALA_MOEDA  \
# ...

# %%
dados_bp = pd.read_csv("Csv/Mundo9dfp_cia_aberta_BPP_con_2021.csv",
                        sep = ";",
                        encoding="ISO-8859-1",
                        decimal = ",")#decimal para virgula

dados_bp
# Out:
#                   CNPJ_CIA    DT_REFER  VERSAO        DENOM_CIA  CD_CVM  \
# 0       00.000.000/0001-91  2021-12-31       2  BCO BRASIL S.A.    1023
# 1       00.000.000/0001-91  2021-12-31       2  BCO BRASIL S.A.    1023
# 2       00.000.000/0001-91  2021-12-31       2  BCO BRASIL S.A.    1023
# 3       00.000.000/0001-91  2021-12-31       2  BCO BRASIL S.A.    1023
# 4       00.000.000/0001-91  2021-12-31       2  BCO BRASIL S.A.    1023
# ...                    ...         ...     ...              ...     ...
# 101159  97.837.181/0001-47  2021-12-31       1       DEXCO S.A.   21091
# 101160  97.837.181/0001-47  2021-12-31       1       DEXCO S.A.   21091
# 101161  97.837.181/0001-47  2021-12-31       1       DEXCO S.A.   21091
# 101162  97.837.181/0001-47  2021-12-31       1       DEXCO S.A.   21091
# 101163  97.837.181/0001-47  2021-12-31       1       DEXCO S.A.   21091
#
#                                            GRUPO_DFP MOEDA ESCALA_MOEDA  \
# ...

# %%
dados_bp = pd.read_csv("Csv/Mundo9dfp_cia_aberta_BPP_con_2021.csv",
                        sep = ";",
                        encoding="ISO-8859-1",
                        decimal = ",",
                        index_col="DT_REFER",
                        usecols=['DT_REFER','DENOM_CIA','ESCALA_MOEDA',#usar DT_REFER como indice
                                 'ORDEM_EXERC','CD_CONTA','DS_CONTA','VL_CONTA'])#usar soemnte essas colunas

dados_bp
# Out:
#                   DENOM_CIA ESCALA_MOEDA ORDEM_EXERC CD_CONTA  \
# DT_REFER
# 2021-12-31  BCO BRASIL S.A.          MIL   PENÚLTIMO        2
# 2021-12-31  BCO BRASIL S.A.          MIL      ÚLTIMO        2
# 2021-12-31  BCO BRASIL S.A.          MIL   PENÚLTIMO     2.01
# 2021-12-31  BCO BRASIL S.A.          MIL      ÚLTIMO     2.01
# 2021-12-31  BCO BRASIL S.A.          MIL   PENÚLTIMO     2.02
# ...                     ...          ...         ...      ...
# 2021-12-31       DEXCO S.A.          MIL      ÚLTIMO  2.03.07
# 2021-12-31       DEXCO S.A.          MIL   PENÚLTIMO  2.03.08
# 2021-12-31       DEXCO S.A.          MIL      ÚLTIMO  2.03.08
# 2021-12-31       DEXCO S.A.          MIL   PENÚLTIMO  2.03.09
# 2021-12-31       DEXCO S.A.          MIL      ÚLTIMO  2.03.09
#
#                                                      DS_CONTA  \
# DT_REFER
# 2021-12-31                                      Passivo Total
# 2021-12-31                                      Passivo Total
# ...

# %%
#Como tranformar dados para CVS?

df_teste = pd.DataFrame({"empresa": ['WEGE3', 'PCAR4', 'PETR4'],
                       "cotacao": [20, 50, 60]}, index = pd.date_range("2022-01-01", periods = 3))


df_teste
# Out:
#            empresa  cotacao
# 2022-01-01   WEGE3       20
# 2022-01-02   PCAR4       50
# 2022-01-03   PETR4       60

# %%
df_teste.to_csv("teste_df.csv",sep=";",mode="a")

# %% [markdown]
# # Exercícios
#
# * Exercício 58: Leia o CSV disponibilizado na aula, contendo informações da DRE das empresas da bolsa brasileira em 2021. Utilize as mesmas colunas utilizadas na leitura do balanço patrimonial passivo.

# %%
df_exercicio = pd.read_csv("Csv/Mundo9dfp_cia_aberta_DRE_con_2021.csv",
                            sep= ";",
                            encoding= "ISO-8859-1",
                            decimal = ",",
                            index_col = "DT_REFER",
                            usecols = ['DT_REFER', 'DENOM_CIA', 'ESCALA_MOEDA',
                                'ORDEM_EXERC', 'CD_CONTA', 'DS_CONTA', 'VL_CONTA'])


df_exercicio
# Out:
#                   DENOM_CIA ESCALA_MOEDA ORDEM_EXERC    CD_CONTA  \
# DT_REFER
# 2021-12-31  BCO BRASIL S.A.          MIL   PENÚLTIMO        3.01
# 2021-12-31  BCO BRASIL S.A.          MIL      ÚLTIMO        3.01
# 2021-12-31  BCO BRASIL S.A.          MIL   PENÚLTIMO     3.01.01
# 2021-12-31  BCO BRASIL S.A.          MIL      ÚLTIMO     3.01.01
# 2021-12-31  BCO BRASIL S.A.          MIL   PENÚLTIMO        3.02
# ...                     ...          ...         ...         ...
# 2021-12-31       DEXCO S.A.          MIL      ÚLTIMO  3.99.01.01
# 2021-12-31       DEXCO S.A.          MIL   PENÚLTIMO     3.99.02
# 2021-12-31       DEXCO S.A.          MIL      ÚLTIMO     3.99.02
# 2021-12-31       DEXCO S.A.          MIL   PENÚLTIMO  3.99.02.01
# 2021-12-31       DEXCO S.A.          MIL      ÚLTIMO  3.99.02.01
#
#                                         DS_CONTA              VL_CONTA
# DT_REFER
# 2021-12-31  Receitas de Intermediação Financeira   98659704.0000000000
# ...
