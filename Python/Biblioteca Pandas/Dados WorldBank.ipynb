# %% [markdown]
# # Mundo 13
#
# ### Leitura e extração de dados

# %% [markdown]
# https://data.worldbank.org/
#
# Esses dados podem servir pra montar um ótimo portfólio diferente.

# %%
from pandas_datareader import wb
from datetime import datetime

# %%
indicadores = wb.get_indicators() #todos os indicadores do MErcado mundial
indicadores
# Out:
#                          id  \
# 0        1.0.HCount.1.90usd
# 1         1.0.HCount.2.5usd
# 2      1.0.HCount.Mid10to50
# 3           1.0.HCount.Ofcl
# 4       1.0.HCount.Poor4uds
# ...                     ...
# 20887               w_F_skl
# 20888               w_M_nsk
# 20889               w_M_skl
# 20890             wpremia_F
# 20891             wpremia_M
#
#                                                     name unit  \
# 0                        Poverty Headcount ($1.90 a day)
# 1                        Poverty Headcount ($2.50 a day)
# 2                  Middle Class ($10-50 a day) Headcount
# 3                Official Moderate Poverty Rate-National
# 4                           Poverty Headcount ($4 a day)
# ...                                                  ...  ...
# 20887     Annual wage for skilled female workers  in US$
# 20888     Annual wage for unskilled male workers  in US$
# 20889       Annual wage for skilled male workers  in US$
# 20890  Wage Premia for Females (the ratio of skilled ...
# 20891  Wage Premia for Males  (the ratio of skilled m...
#
#                                            source  \
# 0                                  LAC Equity Lab
# 1                                  LAC Equity Lab
# 2                                  LAC Equity Lab
# 3                                  LAC Equity Lab
# 4                                  LAC Equity Lab
# ...                                           ...
# 20887  Gender Disaggregated Labor Database (GDLD)
# 20888  Gender Disaggregated Labor Database (GDLD)
# 20889  Gender Disaggregated Labor Database (GDLD)
# 20890  Gender Disaggregated Labor Database (GDLD)
# 20891  Gender Disaggregated Labor Database (GDLD)
#
#                                               sourceNote  \
# 0      The poverty headcount index measures the propo...
# 1      The poverty headcount index measures the propo...
# 2      The poverty headcount index measures the propo...
# 3      The poverty headcount index measures the propo...
# 4      The poverty headcount index measures the propo...
# ...                                                  ...
# 20887
# 20888
# 20889
# 20890
# 20891
#
#                                       sourceOrganization    topics
# 0      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 1      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 2      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 3      b'LAC Equity Lab tabulations of data from Nati...  Poverty
# 4      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# ...                                                  ...       ...
# 20887                                                b''
# 20888                                                b''
# 20889                                                b''
# 20890                                                b''
# 20891                                                b''
#
# [20892 rows x 7 columns]

# %%
indicadores.head(50)
# Out:
#                                id  \
# 0              1.0.HCount.1.90usd
# 1               1.0.HCount.2.5usd
# 2            1.0.HCount.Mid10to50
# 3                 1.0.HCount.Ofcl
# 4             1.0.HCount.Poor4uds
# 5             1.0.HCount.Vul4to10
# 6                1.0.PGap.1.90usd
# 7                 1.0.PGap.2.5usd
# 8               1.0.PGap.Poor4uds
# 9                1.0.PSev.1.90usd
# 10                1.0.PSev.2.5usd
# 11              1.0.PSev.Poor4uds
# 12             1.1.HCount.1.90usd
# 13              1.1.HCount.2.5usd
# 14           1.1.HCount.Mid10to50
# 15                1.1.HCount.Ofcl
# 16            1.1.HCount.Poor4uds
# 17            1.1.HCount.Vul4to10
# 18               1.1.PGap.1.90usd
# 19                1.1.PGap.2.5usd
# 20              1.1.PGap.Poor4uds
# 21               1.1.PSev.1.90usd
# 22                1.1.PSev.2.5usd
# 23              1.1.PSev.Poor4uds
# 24     1.1_ACCESS.ELECTRICITY.TOT
# 25  1.1_TOTAL.FINAL.ENERGY.CONSUM
# 26        1.1_YOUTH.LITERACY.RATE
# 27             1.2.HCount.1.90usd
# 28              1.2.HCount.2.5usd
# 29           1.2.HCount.Mid10to50
# 30                1.2.HCount.Ofcl
# 31            1.2.HCount.Poor4uds
# 32            1.2.HCount.Vul4to10
# 33               1.2.PGap.1.90usd
# 34                1.2.PGap.2.5usd
# 35              1.2.PGap.Poor4uds
# 36               1.2.PSev.1.90usd
# 37                1.2.PSev.2.5usd
# 38              1.2.PSev.Poor4uds
# 39   1.2_ACCESS.ELECTRICITY.RURAL
# 40   1.3_ACCESS.ELECTRICITY.URBAN
# 41                         100000
# 42                        1000000
# 43                         110000
# 44                         110100
# 45                        1101000
# 46                         110110
# 47                        1101100
# 48                         110111
# 49                        1101110
#
#                                                  name unit  \
# 0                     Poverty Headcount ($1.90 a day)
# 1                     Poverty Headcount ($2.50 a day)
# 2               Middle Class ($10-50 a day) Headcount
# 3             Official Moderate Poverty Rate-National
# 4                        Poverty Headcount ($4 a day)
# 5                  Vulnerable ($4-10 a day) Headcount
# 6                           Poverty Gap ($1.90 a day)
# 7                           Poverty Gap ($2.50 a day)
# 8                              Poverty Gap ($4 a day)
# 9                      Poverty Severity ($1.90 a day)
# 10                     Poverty Severity ($2.50 a day)
# 11                        Poverty Severity ($4 a day)
# 12              Poverty Headcount ($1.90 a day)-Rural
# 13              Poverty Headcount ($2.50 a day)-Rural
# 14        Middle Class ($10-50 a day) Headcount-Rural
# 15              Official Moderate Poverty Rate- Rural
# 16                 Poverty Headcount ($4 a day)-Rural
# 17           Vulnerable ($4-10 a day) Headcount-Rural
# 18                    Poverty Gap ($1.90 a day)-Rural
# 19                    Poverty Gap ($2.50 a day)-Rural
# 20                       Poverty Gap ($4 a day)-Rural
# 21               Poverty Severity ($1.90 a day)-Rural
# 22               Poverty Severity ($2.50 a day)-Rural
# 23                  Poverty Severity ($4 a day)-Rural
# 24      Access to electricity (% of total population)
# 25              Total final energy consumption (TFEC)
# 26  Literacy rate, youth total (% of people ages 1...
# 27              Poverty Headcount ($1.90 a day)-Urban
# 28              Poverty Headcount ($2.50 a day)-Urban
# 29        Middle Class ($10-50 a day) Headcount-Urban
# 30               Official Moderate Poverty Rate-Urban
# 31                 Poverty Headcount ($4 a day)-Urban
# 32           Vulnerable ($4-10 a day) Headcount-Urban
# 33                    Poverty Gap ($1.90 a day)-Urban
# 34                    Poverty Gap ($2.50 a day)-Urban
# 35                       Poverty Gap ($4 a day)-Urban
# 36               Poverty Severity ($1.90 a day)-Urban
# 37               Poverty Severity ($2.50 a day)-Urban
# 38                  Poverty Severity ($4 a day)-Urban
# 39      Access to electricity (% of rural population)
# 40      Access to electricity (% of urban population)
# 41                      100000:GROSS DOMESTIC PRODUCT
# 42                     1000000:GROSS DOMESTIC PRODUCT
# 43  110000:INDIVIDUAL CONSUMPTION EXPENDITURE BY H...
# 44            110100:FOOD AND NON-ALCOHOLIC BEVERAGES
# 45           1101000:FOOD AND NON-ALCOHOLIC BEVERAGES
# 46                                        110110:FOOD
# 47                                       1101100:FOOD
# 48                   110111:Bread and cereals (Class)
# 49                          1101110:Bread and cereals
#
#                                          source  \
# 0                                LAC Equity Lab
# 1                                LAC Equity Lab
# 2                                LAC Equity Lab
# 3                                LAC Equity Lab
# 4                                LAC Equity Lab
# 5                                LAC Equity Lab
# 6                                LAC Equity Lab
# 7                                LAC Equity Lab
# 8                                LAC Equity Lab
# 9                                LAC Equity Lab
# 10                               LAC Equity Lab
# 11                               LAC Equity Lab
# 12                               LAC Equity Lab
# 13                               LAC Equity Lab
# 14                               LAC Equity Lab
# 15                               LAC Equity Lab
# 16                               LAC Equity Lab
# 17                               LAC Equity Lab
# 18                               LAC Equity Lab
# 19                               LAC Equity Lab
# 20                               LAC Equity Lab
# 21                               LAC Equity Lab
# 22                               LAC Equity Lab
# 23                               LAC Equity Lab
# 24                   Sustainable Energy for All
# 25                   Sustainable Energy for All
# 26             Global Partnership for Education
# 27                               LAC Equity Lab
# 28                               LAC Equity Lab
# 29                               LAC Equity Lab
# 30                               LAC Equity Lab
# 31                               LAC Equity Lab
# 32                               LAC Equity Lab
# 33                               LAC Equity Lab
# 34                               LAC Equity Lab
# 35                               LAC Equity Lab
# 36                               LAC Equity Lab
# 37                               LAC Equity Lab
# 38                               LAC Equity Lab
# 39                   Sustainable Energy for All
# 40                   Sustainable Energy for All
# 41  International Comparison Program (ICP) 2005
# 42                                     ICP 2017
# 43  International Comparison Program (ICP) 2005
# 44  International Comparison Program (ICP) 2005
# 45                                     ICP 2017
# 46  International Comparison Program (ICP) 2005
# 47                                     ICP 2017
# 48  International Comparison Program (ICP) 2005
# 49                                     ICP 2017
#
#                                            sourceNote  \
# 0   The poverty headcount index measures the propo...
# 1   The poverty headcount index measures the propo...
# 2   The poverty headcount index measures the propo...
# 3   The poverty headcount index measures the propo...
# 4   The poverty headcount index measures the propo...
# 5   The poverty headcount index measures the propo...
# 6   The poverty gap captures the mean aggregate in...
# 7   The poverty gap captures the mean aggregate in...
# 8   The poverty gap captures the mean aggregate in...
# 9   The poverty severity index combines informatio...
# 10  The poverty severity index combines informatio...
# 11  The poverty severity index combines informatio...
# 12  The poverty headcount index measures the propo...
# 13  The poverty headcount index measures the propo...
# 14  The poverty headcount index measures the propo...
# 15  The poverty headcount index measures the propo...
# 16  The poverty headcount index measures the propo...
# 17  The poverty headcount index measures the propo...
# 18  The poverty gap captures the mean aggregate in...
# 19  The poverty gap captures the mean aggregate in...
# 20  The poverty gap captures the mean aggregate in...
# 21  The poverty severity index combines informatio...
# 22  The poverty severity index combines informatio...
# 23  The poverty severity index combines informatio...
# 24  Access to electricity is the percentage of pop...
# 25  Total final energy consumption (TFEC): This in...
# 26  The number of persons aged 15 to 24 years who ...
# 27  The poverty headcount index measures the propo...
# 28  The poverty headcount index measures the propo...
# 29  The poverty headcount index measures the propo...
# 30  The poverty headcount index measures the propo...
# 31  The poverty headcount index measures the propo...
# 32  The poverty headcount index measures the propo...
# 33  The poverty gap captures the mean aggregate in...
# 34  The poverty gap captures the mean aggregate in...
# 35  The poverty gap captures the mean aggregate in...
# 36  The poverty severity index combines informatio...
# 37  The poverty severity index combines informatio...
# 38  The poverty severity index combines informatio...
# 39  Access to electricity is the percentage of rur...
# 40  Access to electricity is the percentage of tot...
# 41
# 42
# 43
# 44
# 45
# 46
# 47
# 48
# 49
#
#                                    sourceOrganization    topics
# 0   b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 1   b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 2   b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 3   b'LAC Equity Lab tabulations of data from Nati...  Poverty
# 4   b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 5   b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 6   b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 7   b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 8   b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 9   b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 10  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 11  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 12  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 13  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 14  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 15  b'LAC Equity Lab tabulations of data from Nati...  Poverty
# 16  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 17  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 18  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 19  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 20  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 21  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 22  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 23  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 24  b'World Bank Global Electrification Database 2...
# 25  b'World Bank and International Energy Agency (...
# 26  b'Source of information: UNESCO Institute for ...
# 27  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 28  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 29  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 30  b'LAC Equity Lab tabulations of data from Nati...  Poverty
# 31  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 32  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 33  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 34  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 35  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 36  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 37  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 38  b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...  Poverty
# 39  b'World Bank Global Electrification Database 2...
# 40  b'World Bank Global Electrification Database 2...
# 41                                                b''
# 42                                                b''
# 43                                                b''
# 44                                                b''
# 45                                                b''
# 46                                                b''
# 47                                                b''
# 48                                                b''
# 49                                                b''

# %%
matches = wb.search('gdp.*capita.*const')

matches
# Out:
#                          id  \
# 691      6.0.GDPpc_constant
# 10634        NY.GDP.PCAP.KD
# 10636        NY.GDP.PCAP.KN
# 10638     NY.GDP.PCAP.PP.KD
# 10639  NY.GDP.PCAP.PP.KD.87
#
#                                                     name unit  \
# 691    GDP per capita, PPP (constant 2011 internation...
# 10634                 GDP per capita (constant 2015 US$)
# 10636                      GDP per capita (constant LCU)
# 10638  GDP per capita, PPP (constant 2017 internation...
# 10639  GDP per capita, PPP (constant 1987 internation...
#
#                              source  \
# 691                  LAC Equity Lab
# 10634  World Development Indicators
# 10636  World Development Indicators
# 10638  World Development Indicators
# 10639         WDI Database Archives
#
#                                               sourceNote  \
# 691    GDP per capita based on purchasing power parit...
# 10634  GDP per capita is gross domestic product divid...
# 10636  GDP per capita is gross domestic product divid...
# 10638  GDP per capita based on purchasing power parit...
# 10639
#
#                                       sourceOrganization            topics
# 691         b'World Development Indicators (World Bank)'  Economy & Growth
# 10634  b'World Bank national accounts data, and OECD ...  Economy & Growth
# 10636  b'World Bank national accounts data, and OECD ...  Economy & Growth
# 10638  b'International Comparison Program, World Bank...  Economy & Growth
# 10639                                                b''

# %%
pobreza = wb.download(indicator='1.0.HCount.1.90usd',
                      country=['MEX','BRA'],
                      start=2000, end=2022)

pobreza
# Out:
#               1.0.HCount.1.90usd
# country year
# Brazil  2014            3.663256
#         2013                 NaN
#         2012            4.591671
#         2011            5.500478
#         2010                 NaN
#         2009            6.175147
#         2008            6.286798
#         2007            7.602658
#         2006            7.944849
#         2005            9.553495
#         2004           11.036233
#         2003           12.709325
#         2002           12.310864
#         2001           13.622047
#         2000                 NaN
# Mexico  2014            5.653357
#         2013                 NaN
#         2012            5.944242
#         2011                 NaN
#         2010            6.593106
#         2009                 NaN
#         2008            7.191222
#         2007                 NaN
#         2006            6.033171
#         2005            8.658200
#         2004            8.299212
#         2003                 NaN
#         2002            9.224252
#         2001                 NaN
#         2000           11.721977

# %% [markdown]
# https://www.worldbank.org/en/topic/poverty/lac-equity-lab1/overview

# %% [markdown]
# # Link com o código dos países:
#
# https://en.wikipedia.org/wiki/List_of_ISO_3166_country_codes

# %%
pib_percapta = wb.download(indicator= 'NY.GDP.PCAP.KD',
                    country= ['BRA','USA','ARG','MEX'],
                    start = 1980, end = 2023)

print(pib_percapta)
# Out:
#                     NY.GDP.PCAP.KD
# country       year
# Argentina     2021    12402.490791
#               2020    11341.268366
#               2019    12716.224204
#               2018    13105.397163
#               2017    13595.037355
# ...                            ...
# United States 1984    33906.351244
#               1983    31893.199049
#               1982    30775.441389
#               1981    31640.677787
#               1980    31161.930725
#
# [168 rows x 1 columns]

# %%
aumento_em_40_anos = pib_percapta.groupby('country').first()/pib_percapta.groupby('country').last()-1


aumento_em_40_anos
# Out:
#                NY.GDP.PCAP.KD
# country
# Argentina            0.207530
# Brazil               0.330800
# Mexico               0.239711
# United States        0.984971

# %%
pib_percapta.loc['Brazil']
# Out:
#       NY.GDP.PCAP.KD
# year
# 2021     8537.939220
# 2020     8204.202726
# 2019     8592.221538
# 2018     8553.876187
# 2017     8470.950789
# 2016     8426.853352
# 2015     8783.225984
# 2014     9183.470768
# 2013     9216.143360
# 2012     9025.324848
# 2011     8935.288057
# 2010     8673.908812
# 2009     8142.770839
# 2008     8231.110269
# 2007     7909.834758
# 2006     7534.551559
# 2005     7325.912358
# 2004     7178.356116
# 2003     6865.181505
# 2002     6868.704165
# 2001     6749.889719
# 2000     6745.865881
# 1999     6551.234548
# 1998     6613.991133
# 1997     6689.207419
# 1996     6567.360357
# 1995     6524.526698
# 1994     6358.686433
# 1993     6103.384553
# 1992     5911.694131
# 1991     6043.439900
# 1990     6086.084870
# 1989     6479.076886
# 1988     6399.492062
# 1987     6528.631318
# 1986     6433.505717
# 1985     6110.365748
# 1984     5788.094130
# 1983     5613.618268
# 1982     5914.572189
# 1981     6001.652206
# 1980     6415.645527

# %% [markdown]
# # Exercícios
#
# * Exercício 62: Busque os dados no banco mundial da evolução da emissão de carbono no mundo que tem como nome "CO2 emissions (kt)" desde 1990. Obs: para puxar dados agregados do mundo, a sigla a ser colocada em Country é "1W"

# %%
#gabarito 62

matches = wb.search('co2')

matches.tail(50)
# Out:
#                         id                                               name  \
# 2373         CC.NCO.GHG.IL  Non-CO2 GHG emissions by sector (Mt CO2 eq) - ...
# 2374         CC.NCO.GHG.IP  Non-CO2 GHG emissions by sector (Mt CO2 eq) - ...
# 2375         CC.NCO.GHG.LU  Non-CO2 GHG emissions by sector (Mt CO2 eq) - ...
# 2376         CC.NCO.GHG.OF  Non-CO2 GHG emissions by sector (Mt CO2 eq) - ...
# 2377         CC.NCO.GHG.WA  Non-CO2 GHG emissions by sector (Mt CO2 eq) - ...
# 6092     EN.ATM.CO2E.CP.KT  CO2 emissions from cement production (thousand...
# 6093     EN.ATM.CO2E.EG.ZS  CO2 intensity (kg per kg of oil equivalent ene...
# 6094     EN.ATM.CO2E.FF.KT  CO2 emissions from fossil-fuels, total (thousa...
# 6095     EN.ATM.CO2E.FF.ZS       CO2 emissions from fossil-fuels (% of total)
# 6096       EN.ATM.CO2E.GDP  CO2 emissions, industrial (kg per 1987 US$ of ...
# 6097     EN.ATM.CO2E.GF.KT  CO2 emissions from gaseous fuel consumption (kt)
# 6098     EN.ATM.CO2E.GF.ZS  CO2 emissions from gaseous fuel consumption (%...
# 6099     EN.ATM.CO2E.GL.KT  CO2 emissions from gas flaring (thousand metri...
# 6100  EN.ATM.CO2E.KD.87.GD  CO2 emissions, industrial (kg per 1987 US$ of ...
# 6101     EN.ATM.CO2E.KD.GD             CO2 emissions (kg per 2015 US$ of GDP)
# 6102        EN.ATM.CO2E.KT                                 CO2 emissions (kt)
# 6103     EN.ATM.CO2E.LF.KT   CO2 emissions from liquid fuel consumption (kt)
# 6104     EN.ATM.CO2E.LF.ZS  CO2 emissions from liquid fuel consumption (% ...
# 6105        EN.ATM.CO2E.PC             CO2 emissions (metric tons per capita)
# 6106     EN.ATM.CO2E.PP.GD                CO2 emissions (kg per PPP $ of GDP)
# 6107  EN.ATM.CO2E.PP.GD.KD           CO2 emissions (kg per 2017 PPP $ of GDP)
# 6108     EN.ATM.CO2E.SF.KT    CO2 emissions from solid fuel consumption (kt)
# 6109     EN.ATM.CO2E.SF.ZS  CO2 emissions from solid fuel consumption (% o...
# 6110     EN.ATM.GHGO.KT.CE  Other greenhouse gas emissions, HFC, PFC and S...
# 6112     EN.ATM.GHGT.KT.CE  Total greenhouse gas emissions (kt of CO2 equi...
# 6114     EN.ATM.HFCG.KT.CE  HFC gas emissions (thousand metric tons of CO2...
# 6115  EN.ATM.METH.AG.KT.CE  Agricultural methane emissions (thousand metri...
# 6117  EN.ATM.METH.EG.KT.CE  Methane emissions in energy sector (thousand m...
# 6120     EN.ATM.METH.KT.CE           Methane emissions (kt of CO2 equivalent)
# 6121        EN.ATM.METH.PC  Methane emissions (kt of CO2 equivalent per ca...
# 6123  EN.ATM.NOXE.AG.KT.CE  Agricultural nitrous oxide emissions (thousand...
# 6125  EN.ATM.NOXE.EG.KT.CE  Nitrous oxide emissions in energy sector (thou...
# 6128  EN.ATM.NOXE.IN.KT.CE  Industrial nitrous oxide emissions (thousand m...
# 6130     EN.ATM.NOXE.KT.CE  Nitrous oxide emissions (thousand metric tons ...
# 6131     EN.ATM.NOXE.MT.CE  Nitrous oxide emissions (metric tons of CO2 eq...
# 6132        EN.ATM.NOXE.PC  Nitrous oxide emissions (metric tons of CO2 eq...
# 6134     EN.ATM.PFCG.KT.CE  PFC gas emissions (thousand metric tons of CO2...
# 6141     EN.ATM.SF6G.KT.CE  SF6 gas emissions (thousand metric tons of CO2...
# 6147     EN.CLC.GHGR.MT.CE  GHG net emissions/removals by LUCF (Mt of CO2 ...
# 6152        EN.CO2.BLDG.MT  CO2 emissions from residential buildings and c...
# 6153        EN.CO2.BLDG.ZS  CO2 emissions from residential buildings and c...
# 6154        EN.CO2.ETOT.MT  CO2 emissions from electricity and heat produc...
# 6155        EN.CO2.ETOT.ZS  CO2 emissions from electricity and heat produc...
# 6156        EN.CO2.MANF.MT  CO2 emissions from manufacturing industries an...
# 6157        EN.CO2.MANF.ZS  CO2 emissions from manufacturing industries an...
# 6158        EN.CO2.OTHX.MT  CO2 emissions from other sectors, excluding re...
# 6159        EN.CO2.OTHX.ZS  CO2 emissions from other sectors, excluding re...
# 6160        EN.CO2.TRAN.MT  CO2 emissions from transport (million metric t...
# 6161        EN.CO2.TRAN.ZS  CO2 emissions from transport (% of total fuel ...
# 7954       IN.ENV.CO2.CONC   CO2 Emission (in thousand metric tons of Carbon)
#
#      unit                                             source  \
# 2373           Country Climate and Development Report (CCDR)
# 2374           Country Climate and Development Report (CCDR)
# 2375           Country Climate and Development Report (CCDR)
# 2376           Country Climate and Development Report (CCDR)
# 2377           Country Climate and Development Report (CCDR)
# 6092                           Africa Development Indicators
# 6093                            World Development Indicators
# 6094                           Africa Development Indicators
# 6095                           Africa Development Indicators
# 6096                                   WDI Database Archives
# 6097                            World Development Indicators
# 6098                            World Development Indicators
# 6099                           Africa Development Indicators
# 6100                                   WDI Database Archives
# 6101                            World Development Indicators
# 6102                            World Development Indicators
# 6103                            World Development Indicators
# 6104                            World Development Indicators
# 6105                            World Development Indicators
# 6106                            World Development Indicators
# 6107                            World Development Indicators
# 6108                            World Development Indicators
# 6109                            World Development Indicators
# 6110                            World Development Indicators
# 6112                            World Development Indicators
# 6114                            World Development Indicators
# 6115                            World Development Indicators
# 6117                            World Development Indicators
# 6120                            World Development Indicators
# 6121                                   WDI Database Archives
# 6123                            World Development Indicators
# 6125                            World Development Indicators
# 6128                                   WDI Database Archives
# 6130                            World Development Indicators
# 6131                                   WDI Database Archives
# 6132                                   WDI Database Archives
# 6134                            World Development Indicators
# 6141                            World Development Indicators
# 6147                            World Development Indicators
# 6152                                   WDI Database Archives
# 6153                            World Development Indicators
# 6154                                   WDI Database Archives
# 6155                            World Development Indicators
# 6156                                   WDI Database Archives
# 6157                            World Development Indicators
# 6158                                   WDI Database Archives
# 6159                            World Development Indicators
# 6160                                   WDI Database Archives
# 6161                            World Development Indicators
# 7954       Country Partnership Strategy for India (FY2013...
#
#                                              sourceNote  \
# 2373  Total non-CO2 emissions (including LUCF) are g...
# 2374  Industrial Processes sector non-CO2 emissions ...
# 2375
# 2376  Other fuel combustion sector non-CO2 emissions...
# 2377  Waste sector non-CO2 emissions are generated f...
# 6092  Carbon dioxide emissions from cement productio...
# 6093  Carbon dioxide emissions from solid fuel consu...
# 6094  Fossil fuel is any hydrocarbon deposit that ca...
# 6095  Fossil fuel is any hydrocarbon deposit that ca...
# 6096
# 6097  Carbon dioxide emissions from liquid fuel cons...
# 6098  Carbon dioxide emissions from liquid fuel cons...
# 6099  Carbon dioxide emissions from gas flaring fuel...
# 6100
# 6101  Carbon dioxide emissions are those stemming fr...
# 6102  Carbon dioxide emissions are those stemming fr...
# 6103  Carbon dioxide emissions from liquid fuel cons...
# 6104  Carbon dioxide emissions from liquid fuel cons...
# 6105  Carbon dioxide emissions are those stemming fr...
# 6106  Carbon dioxide emissions are those stemming fr...
# 6107  Carbon dioxide emissions are those stemming fr...
# 6108  Carbon dioxide emissions from solid fuel consu...
# 6109  Carbon dioxide emissions from solid fuel consu...
# 6110  Other greenhouse gas emissions are by-product ...
# 6112  Total greenhouse gas emissions in kt of CO2 eq...
# 6114  Hydrofluorocarbons, used as a replacement for ...
# 6115  Agricultural methane emissions are emissions f...
# 6117  Methane emissions from energy processes are em...
# 6120  Methane emissions are those stemming from huma...
# 6121
# 6123  Agricultural nitrous oxide emissions are emiss...
# 6125  Nitrous oxide emissions from energy processes ...
# 6128
# 6130  Nitrous oxide emissions are emissions from agr...
# 6131
# 6132
# 6134  Perfluorocarbons, used as a replacement for ch...
# 6141  Sulfur hexafluoride is used largely to insulat...
# 6147  GHG net emissions/removals by LUCF refers to c...
# 6152  CO2 emissions from residential buildings and c...
# 6153  CO2 emissions from residential buildings and c...
# 6154  CO2 emissions from electricity and heat produc...
# 6155  CO2 emissions from electricity and heat produc...
# 6156  CO2 emissions from manufacturing industries an...
# 6157  CO2 emissions from manufacturing industries an...
# 6158  CO2 emissions from other sectors, less residen...
# 6159  CO2 emissions from other sectors, less residen...
# 6160  CO2 emissions from transport contains emission...
# 6161  CO2 emissions from transport contains emission...
# 7954
#
#                                      sourceOrganization  \
# 2373  b'Climate Watch. 2020. Washington, DC: World R...
# 2374  b'Climate Watch. 2020. Washington, DC: World R...
# 2375                                                b''
# 2376  b'Climate Watch. 2020. Washington, DC: World R...
# 2377  b'Climate Watch. 2020. Washington, DC: World R...
# 6092  b'Food and Agriculture Organization, electroni...
# 6093  b'Carbon Dioxide Information Analysis Center, ...
# 6094  b'Food and Agriculture Organization, electroni...
# 6095  b'Food and Agriculture Organization, electroni...
# 6096                                                b''
# 6097  b'Carbon Dioxide Information Analysis Center, ...
# 6098  b'Carbon Dioxide Information Analysis Center, ...
# 6099  b'Food and Agriculture Organization, electroni...
# 6100                                                b''
# 6101  b"Climate Watch. 2020. GHG Emissions. Washingt...
# 6102  b'Climate Watch. 2020. GHG Emissions. Washingt...
# 6103  b'Carbon Dioxide Information Analysis Center, ...
# 6104  b'Carbon Dioxide Information Analysis Center, ...
# 6105  b"Climate Watch. 2020. GHG Emissions. Washingt...
# 6106  b"Climate Watch. 2020. GHG Emissions. Washingt...
# 6107  b"Climate Watch. 2020. GHG Emissions. Washingt...
# 6108  b'Carbon Dioxide Information Analysis Center, ...
# 6109  b'Carbon Dioxide Information Analysis Center, ...
# 6110  b'World Bank staff estimates from original sou...
# 6112  b'Climate Watch. 2020. GHG Emissions. Washingt...
# 6114  b'European Commission, Joint Research Centre (...
# 6115  b'Climate Watch. 2020. GHG Emissions. Washingt...
# 6117  b'Climate Watch. 2020. GHG Emissions. Washingt...
# 6120  b'Climate Watch. 2020. GHG Emissions. Washingt...
# 6121                                                b''
# 6123  b'Climate Watch. 2020. GHG Emissions. Washingt...
# 6125  b'Climate Watch. 2020. GHG Emissions. Washingt...
# 6128                                                b''
# 6130  b'Climate Watch. 2020. GHG Emissions. Washingt...
# 6131                                                b''
# 6132                                                b''
# 6134  b'European Commission, Joint Research Centre (...
# 6141  b'European Commission, Joint Research Centre (...
# 6147  b'United Nations Framework Convention on Clima...
# 6152  b'IEA Statistics  OECD/IEA 2014 (http://www.ie...
# 6153  b'IEA Statistics  OECD/IEA 2014 (http://www.ie...
# 6154  b'IEA Statistics  OECD/IEA 2014 (http://www.ie...
# 6155  b'IEA Statistics  OECD/IEA 2014 (http://www.ie...
# 6156  b'IEA Statistics  OECD/IEA 2014 (http://www.ie...
# 6157  b'IEA Statistics  OECD/IEA 2014 (http://www.ie...
# 6158  b'IEA Statistics  OECD/IEA 2014 (http://www.ie...
# 6159  b'IEA Statistics  OECD/IEA 2014 (http://www.ie...
# 6160  b'IEA Statistics  OECD/IEA 2014 (http://www.ie...
# 6161  b'IEA Statistics  OECD/IEA 2014 (http://www.ie...
# 7954                                                b''
#
#                                                 topics
# 2373
# 2374
# 2375
# 2376
# 2377
# 6092
# 6093                     Climate Change ; Environment
# 6094
# 6095
# 6096
# 6097                     Climate Change ; Environment
# 6098  Energy & Mining  ; Climate Change ; Environment
# 6099
# 6100
# 6101                     Climate Change ; Environment
# 6102                     Climate Change ; Environment
# 6103  Energy & Mining  ; Climate Change ; Environment
# 6104                     Climate Change ; Environment
# 6105                     Climate Change ; Environment
# 6106                     Climate Change ; Environment
# 6107                     Climate Change ; Environment
# 6108                     Climate Change ; Environment
# 6109                     Climate Change ; Environment
# 6110                     Climate Change ; Environment
# 6112                     Climate Change ; Environment
# 6114                     Climate Change ; Environment
# 6115  Agriculture & Rural Development   ; Environment
# 6117                   Energy & Mining  ; Environment
# 6120                     Climate Change ; Environment
# 6121
# 6123  Agriculture & Rural Development   ; Environment
# 6125                   Energy & Mining  ; Environment
# 6128
# 6130                     Climate Change ; Environment
# 6131
# 6132
# 6134                     Climate Change ; Environment
# 6141                     Climate Change ; Environment
# 6147                     Climate Change ; Environment
# 6152
# 6153                                      Environment
# 6154
# 6155                                      Environment
# 6156
# 6157                                      Environment
# 6158
# 6159                                      Environment
# 6160
# 6161                                      Environment
# 7954

# %%
co2 = wb.download(indicator='EN.ATM.CO2E.KT', 
                      country=['BR'], 
                      start=1990, end=2022)

print(co2)

co2 = co2.dropna()
co2 = co2.droplevel(level = 0)
co2 = co2.sort_index()
co2
co2.plot()
# Out:
#               EN.ATM.CO2E.KT
# country year
# Brazil  2021             NaN
#         2020             NaN
#         2019   434299.987793
#         2018   433989.990234
#         2017   456489.990234
#         2016   447079.986572
#         2015   485339.996338
#         2014   511619.995117
#         2013   486839.996338
#         2012   454230.010986
#         2011   418309.997559
#         2010   397929.992676
#         2009   350000.000000
#         2008   373630.004883
#         2007   352559.997559
#         2006   335619.995117
#         2005   331690.002441
#         2004   328519.989014
#         2003   310809.997559
#         2002   317760.009766
#         2001   319380.000000
#         2000   313670.000000
#         1999   300960.000000
#         1998   290590.000000
#         1997   281330.000000
#         1996   262410.000000
#         1995   241280.000000
#         1994   222500.000000
#         1993   215260.000000
#         1992   207870.000000
#         1991   205480.000000
#         1990   197900.000000
# <AxesSubplot: xlabel='year'>
